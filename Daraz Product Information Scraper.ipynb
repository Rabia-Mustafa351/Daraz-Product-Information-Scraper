# %% [markdown]
# # Name: RABIA MUSTAFA
# # Roll No.:20I-1853
# # Assignment 6

# %% [markdown]
# # Instruction

# %% [markdown]
# 1. Don’t plagiarize, Plagiarism would lead to straight zero
# 2. Clearly mention your NAME and ROLL NO#.
# 3. Late submissions are not allowed. Start Early.

# %%
#import libraries
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# # Question 1

# %% [markdown]
# Scrape 2 pages of the reviews for a single product listing using product URL.<br /> Note: Product must have more than 1 review page. The code must be generic and should work for every product listing URL, with proper checks in place.

# %%
search_term = input('Enter search term: ')

# %%
options=Options()
driver = webdriver.Chrome(ChromeDriverManager().install())
#search_term='straightners'
driver.get('https://www.daraz.pk/wow/gcp/daraz/megascenario/pk/11-11-2021/11-11-2021-the-worlds-biggest-sale?_mkt_tracker=g&_mkt_campaign=15163746206&_mkt_adgroup=132983551087&_mkt_creative=558689681739&_mkt_src=gg&isdl=y&aff_short_key=_7au92&gclid=Cj0KCQiA4b2MBhD2ARIsAIrcB-SlYK8FycBdFN2eAYL7ReJIzQC1-bV6Xg5hk74G_9qwIjEP_eO3--QaArSXEALw_wcB')
# main website will be get open 
time.sleep(5)
driver.find_element_by_xpath('//*[@id="q"]').send_keys(search_term + Keys.RETURN)
time.sleep(5)
# a product will be searched 
driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div[1]/div/div/div[2]/div[2]/a').click()
revew=[]
name=[]
q=1
for i in range(2):
    for i in range(5):
        s=str(q)
        revew.append(driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[1]/div['+s+']/div[3]/div[1]').text)
        name.append(driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[1]/div['+s+']/div[2]/span[1]').text)
        q=q+1
    driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[2]/div/div/button[2]').click()
    q=1
    time.sleep(5)
# removing additional info from name string
n=name
st=""
c=0
newl=[]
for i in n:
    s=i
    #print(s)
    c=0
    st=""
    for j in s:
        if j==" ":
            c=1
        if c==1:
            st=st+j 
    newl.append(st)
newl
# lists of name and revews are now ready
dic={
    "Name":newl,
    "Reviews":revew
}
df=pd.DataFrame(dic)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST chromedriver version for 95.0.4638 google-chrome
# Driver [C:\Users\HP\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# <ipython-input-306-76fa7d5c6163>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# <ipython-input-306-76fa7d5c6163>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="q"]').send_keys(search_term + Keys.RETURN)
# <ipython-input-306-76fa7d5c6163>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div[1]/div/div/div[2]/div[2]/a').click()
# ...

# %%
df
# Out:
#                Name                                            Reviews
# 0             3***9  This is my 2nd product from Daraz, and believe...
# 1       Muhammad Y.  Product is smartly packed. Look smart working ...
# 2             3***5  Bhu hi Acha mini hair straightener hai bags ma...
# 3        Arsalan T.      Awesome straightener love it delivery on time
# 4             3***4  it was first time to order electronic gadget f...
# 5   Aftabshakeel S.  This is good product.mujy acha laga ye mini ha...
# 6             3***2  yeh surf minihair  straightener hai   straight...
# 7             3***1  Aw www some\nThe best product\nRecommended.......
# 8             3***8  thanks daraz😍 I got my parcel❤  its same as sh...
# 9          sidra N.  Very nice experience saller recommended will o...

# %%
#Output
df
# Out:
#            Name                                        Review text
# 0     Nabeel B.  Cellphone is great, was delivered on said time...
# 1     Salman R.  Great response excellent delivery time and pro...
# 2   Mohammad H.  One of the best in it's category. highly recom...
# 3         M***.        Very good product daraz good service thankx
# 4      hamxa M.                  Original product and good packing
# 5    Saqlain A.  Sir warranty card pr koi date ya sign nai to b...
# 6          M D.  Mobile is original but seller is too lazy in t...
# 7         N***.      Phone is perfect but now prices are increased
# 8      umair K.                   best phone in this price range.
# 9      Imran K.                                 original product 👍

# %% [markdown]
# # Question 2

# %% [markdown]
# Scrape 80 items for a keyword search e.g., 'mobile covers'<br/>Note: Must use "click()" function of webElement, URL changing for pages is not allowed. The code must be generic and should work for every keyword, with proper checks in place. Bonus for also scraping country and Daraz Mall availability.

# %%
query = 'mobile covers'
options=Options()
driver = webdriver.Chrome(ChromeDriverManager().install())
query = query.replace(' ', '%20')
qry=f'{query}'
u='https://www.daraz.pk/catalog/?q='+qry+'&_keyori=ss&from=input&spm=a2a0e.searchlist.search.go.1d974daaePmvbP'
driver.get(u)
time.sleep(7)
i=1      
l=[]

for j in range(40):
    q=str(i)
    time.sleep(7)
    driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+q+']/div/div/div[2]/div[2]').click()
    time.sleep(7) 
    i=i+1
    try:
        for k in driver.find_elements_by_class_name('score-average'):
            l.append(k.text)
            print(k.text)
    except:
            l.append(0)
    driver.back()
driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[3]/div/ul/li[9]/a').click()
i=1
for j in range(40):
    q=str(i)
    time.sleep(7)
    driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+q+']/div/div/div[2]/div[2]').click()
    time.sleep(7) 
    i=i+1
    try:
        for k in driver.find_elements_by_class_name('score-average'):
            l.append(k.text)
            print(k.text)
    except:
            l.append(0)
    driver.back()
print(l)
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 96.0.4664
# [WDM] - Get LATEST driver version for 96.0.4664
# [WDM] - Driver [C:\Users\HP\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# <ipython-input-8-eaafc3a67825>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# <ipython-input-8-eaafc3a67825>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+q+']/div/div/div[2]/div[2]').click()
# <ipython-input-8-eaafc3a67825>:19: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for k in driver.find_elements_by_class_name('score-average'):
# 4.7
# 4.9
# 4.2
# 4.7
# 5.0
# 4.8
# 4.9
# 4.0
# 5.0
# 5.0
# 4.5
# ...

# %%
dic={
    "Names":names,
    "price":price,
    #"Stars":stars,
    "Revews":revews
}
d=pd.DataFrame(dic)
()
# Out:
#                                                 Names    price Revews
# 75                    IPhone 6 OR 6S Armor Back Cover  Rs. 420   (50)
# 76  Huawei Y7 Prime 2018 Soft Shock Proof Jelly Ba...  Rs. 125   (82)
# 77                    Huawei Y7 Prime 2019 Back Cover  Rs. 135   (84)
# 78  Huawei Honor 8X Airbag Case Anti Shock and Ant...  Rs. 139   (49)
# 79  Luxury 6D Plating Soft Casing Silicone Square ...  Rs. 479   (36)

# %%
    
df
# Out:
# Empty DataFrame
# Columns: [Product Name, Original Price, Discounted Price, Discount Percentage, Ratings, Revew1, Revew2, Revew3]
# Index: []

# %% [markdown]
# # Question 3

# %% [markdown]
# Which Products are on Flash sale? Display Product name, Actual Price, Discounted Price, Discount Percentage, Rating, No. of Reviews, Top 3 reviews displayed.
# Display output must be like this. Products may vary.

# %%
options=Options()
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.daraz.pk/#') 
time.sleep(7)
driver.find_element_by_xpath('//*[@id="hp-flash-sale"]/div[2]/div[1]/a').click()

names=[]
orignalprice=[]
stars=[]
discountedPrice=[]
disPercentage=[]
ratings=[]
revew2=[]
revew1=[]
revew3=[]
st=1
st2=""
for i in range(25):
    st2=str(st)
    time.sleep(5)
    for m in driver.find_elements_by_xpath('//*[@id="campaign-1637348400000"]/div/a['+st2+']/div/div[2]/div[1]'):
        time.sleep(7)
        m.click()
        for m in driver.find_elements_by_class_name('pdp-mod-product-badge-wrapper'): # name
            k=m.find_element_by_class_name('pdp-mod-product-badge-title').text
            names.append(k)
            print(k)
        for m in driver.find_elements_by_class_name('score'):    # stars
            k=m.find_element_by_class_name('score-average').text
            stars.append(k)
            print(k)

        for m in driver.find_elements_by_class_name('origin-block'):   # discount  percentage
            k=m.find_element_by_class_name('pdp-product-price__discount').text
            print(k)
            disPercentage.append(k)
        k=driver.find_element_by_xpath('//*[@id="module_product_price_1"]/div/div/span').text #discounted price
        print(k)
        discountedPrice.append(k)
        k=driver.find_element_by_xpath('//*[@id="module_product_price_1"]/div/div/div/span[1]').text #original price
        print(k)
        orignalprice.append(k)
        #for m in driver.find_elements_by_class_name('pdp-product-price'): #discounted price
            #k=m.find_element_by_class_name('pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl').text
            #print(k) 
        #for m in driver.find_elements_by_class_name('pdp-mod-product-price'):  # discounted price
            #k=m.find_element_by_class_name(' pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl').text
            #print(k)
        for m in driver.find_elements_by_class_name('container-star pdp-review-summary__stars pdp-stars_size_s'):
            k=m.find_element_by_class_name('pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link').text
            print(k)
        for m in driver.find_elements_by_class_name('summary'):
            k=m.find_element_by_class_name('count').text
            print(k)
            ratings.append(k)
        k=driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[1]/div[1]/div[3]/div[1]').text
        print(k)
        revew1.append(k)
        k=driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[1]/div[2]/div[3]/div[1]').text
        print(k)
        revew2.append(k)
        k=driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[1]/div[3]/div[3]/div[1]').text
        print(k)
        revew3.append(k)
        driver.back()
        time.sleep(5)
        st=st+1
        print(st)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\HP\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# <ipython-input-10-1d1b1fbb987a>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# <ipython-input-10-1d1b1fbb987a>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="hp-flash-sale"]/div[2]/div[1]/a').click()
# <ipython-input-10-1d1b1fbb987a>:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for m in driver.find_elements_by_xpath('//*[@id="campaign-1637348400000"]/div/a['+st2+']/div/div[2]/div[1]'):
# ...

# %%
dictionary={
    'Product Name':names,
    'Original Price':orignalprice,
    'Discounted Price':discountedPrice,
    'Discount Percentage':disPercentage,
    'Ratings':ratings,
    'Revew1':revew1,
    'Revew2':revew2,
    'Revew3':revew3
}

d=pd.DataFrame(dictionary)
d
# Out:
#                                         Product Name Original Price  \
# 0        i12_air buds / Earphones With Charging Case      Rs. 1,999
# 1  I7S AND i12 Double Wireless Bluetooth Hand Fre...        Rs. 525
# 2  IELGY Pleated waist slimming French retro slee...      Rs. 4,424
# 3  FRAKIN 15 Holes Scarf Hanger Multi Scarves Dis...        Rs. 350
#
#   Discounted Price Discount Percentage      Ratings  \
# 0          Rs. 630                -68%  143 Ratings
# 1          Rs. 320                -39%  667 Ratings
# 2        Rs. 1,576                -64%   44 Ratings
# 3          Rs. 235                -33%  163 Ratings
#
#                                               Revew1  \
# 0  This was my first experience and was very good...
# 1  packing Kuli Hoi thi pata Nahi new hai ya used...
# 2  This is beyond my expectation.  I ordered for ...
# 3  jesa dikhaya gya blkul wesa h bheja h thnks sl...
#
#                                               Revew2  \
# ...

# %%
d.to_csv('info.csv')

# %%
#Run this cell to see output
pd.read_csv('sample.csv')

# %% [markdown]
# # Question 4

# %% [markdown]
# #### Submit .py file
